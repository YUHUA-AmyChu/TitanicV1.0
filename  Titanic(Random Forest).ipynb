# %%
from sklearn import preprocessing 
from sklearn.model_selection import GridSearchCV 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import RandomForestRegressor

import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.options.mode.chained_assignment = None

# %%
train = pd.read_csv("Titanic/train.csv")
test = pd.read_csv("Titanic/test.csv")
submit = pd.read_csv('Titanic/gender_submission.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.options.display.max_rows = 891
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df = train.append(test)
pd.options.display.max_rows = 1309
df
# Out:
# /var/folders/4t/yv8q1_017m726db87cx1327m0000gn/T/ipykernel_46849/3401168200.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = train.append(test)
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# 5              6       0.0       3
# 6              7       0.0       1
# 7              8       0.0       3
# 8              9       1.0       3
# 9             10       1.0       2
# 10            11       1.0       3
# 11            12       1.0       1
# 12            13       0.0       3
# 13            14       0.0       3
# 14            15       0.0       3
# 15            16       1.0       2
# 16            17       0.0       3
# 17            18       1.0       2
# 18            19       0.0       3
# ...

# %%
df.reset_index(inplace=True, drop=True)
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# 5               6       0.0       3
# 6               7       0.0       1
# 7               8       0.0       3
# 8               9       1.0       3
# 9              10       1.0       2
# 10             11       1.0       3
# 11             12       1.0       1
# 12             13       0.0       3
# 13             14       0.0       3
# 14             15       0.0       3
# 15             16       1.0       2
# 16             17       0.0       3
# 17             18       1.0       2
# 18             19       0.0       3
# 19             20       1.0       3
# 20             21       0.0       2
# 21             22       1.0       2
# 22             23       1.0       3
# 23             24       1.0       1
# 24             25       0.0       3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
sns.countplot(data=df,x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(data=df,x=df["Pclass"], hue=df['Survived'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(data=df,x=df['Sex'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(data=df,x=df['Embarked'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# g = sns.FacetGrid(df, col='Survived')
# g.map(sns.distplot, 'Age', kde=False)

# %%
sns.set_theme(style="darkgrid")
sns.histplot(data=df, x="Age", kde=True, bins = 5)
plt.show()
g = sns.FacetGrid(df, col='Survived')
g.map(sns.displot,'Age',kde=False)
# Out:
# /Users/robert/anaconda3/lib/python3.10/site-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /Users/robert/anaconda3/lib/python3.10/site-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.FacetGrid(df, col='Survived')
g.map(sns.distplot, 'Age', kde=False)
# Out:
# /Users/robert/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /Users/robert/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
g = sns.FacetGrid(df, col='Survived')
g.map(sns.distplot, 'Fare', kde=False)
# Out:
# /Users/robert/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /Users/robert/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
g = sns.FacetGrid(df, col='Survived')
g.map(sns.distplot, 'Parch', kde=False)
# Out:
# /Users/robert/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /Users/robert/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
g = sns.FacetGrid(df, col='Survived')
g.map(sns.distplot, 'SibSp', kde=False)
# Out:
# /Users/robert/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /Users/robert/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df['Family_Size'] = df['Parch'] + df['SibSp']

# %%
g = sns.FacetGrid(df, col='Survived')
g.map(sns.distplot, 'Family_Size', kde=False)
# Out:
# /Users/robert/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /Users/robert/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df['Title1'] = df['Name'].str.split(", ", expand=True)[1]

# %%
df['Name'].str.split(", ", expand=True).head(3)
# Out:
#            0                                           1
# 0     Braund                             Mr. Owen Harris
# 1    Cumings  Mrs. John Bradley (Florence Briggs Thayer)
# 2  Heikkinen                                 Miss. Laina

# %%
df['Title1'].head(3)
# Out:
# 0                               Mr. Owen Harris
# 1    Mrs. John Bradley (Florence Briggs Thayer)
# 2                                   Miss. Laina
# Name: Title1, dtype: object

# %%
df['Title1'] = df['Title1'].str.split(".", expand=True)[0]

# %%
df['Title1'].head(3)
# Out:
# 0      Mr
# 1     Mrs
# 2    Miss
# Name: Title1, dtype: object

# %%
df['Title1'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer', 'Dona'], dtype=object)

# %%
pd.crosstab(df['Title1'],df['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_6ac1e_row0_col0, #T_6ac1e_row0_col1, #T_6ac1e_row0_col2, #T_6ac1e_row0_col4, #T_6ac1e_row0_col5, #T_6ac1e_row0_col7, #T_6ac1e_row0_col8, #T_6ac1e_row0_col12, #T_6ac1e_row0_col15, #T_6ac1e_row0_col16, #T_6ac1e_row1_col3, #T_6ac1e_row1_col6, #T_6ac1e_row1_col9, #T_6ac1e_row1_col10, #T_6ac1e_row1_col11, #T_6ac1e_row1_col13, #T_6ac1e_row1_col14, #T_6ac1e_row1_col17 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_6ac1e_row0_col3, #T_6ac1e_row0_col6, #T_6ac1e_row0_col9, #T_6ac1e_row0_col10, #T_6ac1e_row0_col11, #T_6ac1e_row0_col13, #T_6ac1e_row0_col14, #T_6ac1e_row0_col17, #T_6ac1e_row1_col0, #T_6ac1e_row1_col1, #T_6ac1e_row1_col2, #T_6ac1e_row1_col4, #T_6ac1e_row1_col5, #T_6ac1e_row1_col7, #T_6ac1e_row1_col8, #T_6ac1e_row1_col12, #T_6ac1e_row1_col15, #T_6ac1e_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6ac1e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Title1</th>
# ...

# %%
pd.crosstab(df['Title1'],df['Survived']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_c646a_row0_col0, #T_c646a_row0_col2, #T_c646a_row0_col3, #T_c646a_row0_col4, #T_c646a_row0_col11, #T_c646a_row0_col14, #T_c646a_row1_col5, #T_c646a_row1_col7, #T_c646a_row1_col8, #T_c646a_row1_col9, #T_c646a_row1_col10, #T_c646a_row1_col12, #T_c646a_row1_col13, #T_c646a_row1_col15, #T_c646a_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_c646a_row0_col1, #T_c646a_row0_col5, #T_c646a_row0_col6, #T_c646a_row0_col7, #T_c646a_row0_col8, #T_c646a_row0_col9, #T_c646a_row0_col10, #T_c646a_row0_col12, #T_c646a_row0_col13, #T_c646a_row0_col15, #T_c646a_row0_col16, #T_c646a_row1_col0, #T_c646a_row1_col1, #T_c646a_row1_col2, #T_c646a_row1_col3, #T_c646a_row1_col4, #T_c646a_row1_col6, #T_c646a_row1_col11, #T_c646a_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# </style>
# <table id="T_c646a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Title1</th>
# ...

# %%
df.groupby(['Title1'])['Age'].mean()
# Out:
# Title1
# Capt            70.000000
# Col             54.000000
# Don             40.000000
# Dona            39.000000
# Dr              43.571429
# Jonkheer        38.000000
# Lady            48.000000
# Major           48.500000
# Master           5.482642
# Miss            21.774238
# Mlle            24.000000
# Mme             24.000000
# Mr              32.252151
# Mrs             36.994118
# Ms              28.000000
# Rev             41.250000
# Sir             49.000000
# the Countess    33.000000
# Name: Age, dtype: float64

# %%
df.groupby(['Title1','Pclass'])['Age'].mean()
# Out:
# Title1        Pclass
# Capt          1         70.000000
# Col           1         54.000000
# Don           1         40.000000
# Dona          1         39.000000
# Dr            1         45.600000
#               2         38.500000
# Jonkheer      1         38.000000
# Lady          1         48.000000
# Major         1         48.500000
# Master        1          6.984000
#               2          2.757273
#               3          6.090000
# Miss          1         30.338983
#               2         20.717083
#               3         17.360874
# Mlle          1         24.000000
# Mme           1         24.000000
# Mr            1         41.450758
#               2         32.346715
#               3         28.318910
# Mrs           1         43.208955
#               2         33.518519
#               3         32.326531
# Ms            2         28.000000
#               3               NaN
# Rev           2         41.250000
# Sir           1         49.000000
# ...

# %%
df['Title2'] = df['Title1'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','the Countess','Jonkheer','Col','Rev','Capt','Sir','Don','Dona'],
         ['Miss','Mrs','Miss','Mr','Mr','Mrs','Mrs','Mr','Mr','Mr','Mr','Mr','Mr','Mrs'])

# %%
df['Title2'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master'], dtype=object)

# %%
df.groupby(['Title2'])['Age'].mean()
# Out:
# Title2
# Master     5.482642
# Miss      21.824366
# Mr        32.811056
# Mrs       36.971264
# Name: Age, dtype: float64

# %%
df.groupby(['Title2','Pclass'])['Age'].mean()
# Out:
# Title2  Pclass
# Master  1          6.984000
#         2          2.757273
#         3          6.090000
# Miss    1         30.131148
#         2         20.865714
#         3         17.360874
# Mr      1         42.241497
#         2         32.914966
#         3         28.318910
# Mrs     1         42.802817
#         2         33.518519
#         3         32.326531
# Name: Age, dtype: float64

# %%
pd.crosstab(df['Title2'],df['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_bc1ce_row0_col0, #T_bc1ce_row0_col2, #T_bc1ce_row1_col1, #T_bc1ce_row1_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_bc1ce_row0_col1, #T_bc1ce_row0_col3, #T_bc1ce_row1_col0, #T_bc1ce_row1_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bc1ce">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Title2</th>
#       <th id="T_bc1ce_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_bc1ce_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_bc1ce_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_bc1ce_level0_col3" class="col_heading level0 col3" >Mrs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
# ...

# %%
pd.crosstab(df['Title2'],df['Survived']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_94b80_row0_col0, #T_94b80_row0_col1, #T_94b80_row0_col3, #T_94b80_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_94b80_row0_col2, #T_94b80_row1_col0, #T_94b80_row1_col1, #T_94b80_row1_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_94b80">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Title2</th>
#       <th id="T_94b80_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_94b80_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_94b80_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_94b80_level0_col3" class="col_heading level0 col3" >Mrs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
# ...

# %%
list(df.groupby(['Title2','Pclass'])['Age'].mean().iteritems())[:3]
# Out:
# /var/folders/4t/yv8q1_017m726db87cx1327m0000gn/T/ipykernel_46849/2302031256.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   list(df.groupby(['Title2','Pclass'])['Age'].mean().iteritems())[:3]
# [(('Master', 1), 6.984),
#  (('Master', 2), 2.7572727272727273),
#  (('Master', 3), 6.090000000000001)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  Family_Size  1309 non-null   int64
#  13  Title1       1309 non-null   object
#  14  Title2       1309 non-null   object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 153.5+ KB

# %%
df['Ticket']
# Out:
# 0                A/5 21171
# 1                 PC 17599
# 2         STON/O2. 3101282
# 3                   113803
# 4                   373450
# 5                   330877
# 6                    17463
# 7                   349909
# 8                   347742
# 9                   237736
# 10                 PP 9549
# 11                  113783
# 12               A/5. 2151
# 13                  347082
# 14                  350406
# 15                  248706
# 16                  382652
# 17                  244373
# 18                  345763
# 19                    2649
# 20                  239865
# 21                  248698
# 22                  330923
# 23                  113788
# 24                  349909
# 25                  347077
# 26                    2631
# 27                   19950
# 28                  330959
# 29                  349216
# 30                PC 17601
# 31                PC 17569
# 32                  335677
# 33              C.A. 24579
# ...

# %%
df['Ticket_info'] = df['Ticket'].apply(lambda x : x.replace(".","").replace("/","").strip().split(' ')[0] if not x.isdigit() else 'X')

# %%
df['Ticket_info'].unique()
# Out:
# array(['A5', 'PC', 'STONO2', 'X', 'PP', 'CA', 'SCParis', 'SCA4', 'A4',
#        'SP', 'SOC', 'WC', 'SOTONOQ', 'WEP', 'STONO', 'C', 'SCPARIS',
#        'SOP', 'Fa', 'LINE', 'FCC', 'SWPP', 'SCOW', 'PPP', 'SC', 'SCAH',
#        'AS', 'SOPP', 'FC', 'SOTONO2', 'CASOTON', 'SCA3', 'STONOQ', 'AQ4',
#        'A', 'LP', 'AQ3'], dtype=object)

# %%
plt.figure(figsize=(24,6))
sns.countplot(data=df,x=df['Ticket_info'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Ticket_info', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  Family_Size  1309 non-null   int64
#  13  Title1       1309 non-null   object
#  14  Title2       1309 non-null   object
#  15  Ticket_info  1309 non-null   object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 163.8+ KB

# %%
sns.countplot(data=df,x=df['Embarked'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
df['Embarked'] = df['Embarked'].fillna('s')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1309 non-null   object
#  12  Family_Size  1309 non-null   int64
#  13  Title1       1309 non-null   object
#  14  Title2       1309 non-null   object
#  15  Ticket_info  1309 non-null   object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 163.8+ KB

# %%
df['Fare'] = df['Fare'].fillna(df['Fare'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1309 non-null   object
#  12  Family_Size  1309 non-null   int64
#  13  Title1       1309 non-null   object
#  14  Title2       1309 non-null   object
#  15  Ticket_info  1309 non-null   object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 163.8+ KB

# %%
df['Cabin']
# Out:
# 0                   NaN
# 1                   C85
# 2                   NaN
# 3                  C123
# 4                   NaN
# 5                   NaN
# 6                   E46
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                   G6
# 11                 C103
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  D56
# 22                  NaN
# 23                   A6
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27          C23 C25 C27
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  B78
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# 37                  NaN
# ...

# %%
df["Cabin"] = df['Cabin'].apply(lambda x : str(x)[0] if not pd.isnull(x) else 'NoCabin')

# %%
df["Cabin"].unique()
# Out:
# array(['NoCabin', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
sns.countplot(data = df,x=df['Cabin'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Cabin', ylabel='count'>

# %%
df['Embarked']
# Out:
# 0       S
# 1       C
# 2       S
# 3       S
# 4       S
# 5       Q
# 6       S
# 7       S
# 8       S
# 9       C
# 10      S
# 11      S
# 12      S
# 13      S
# 14      S
# 15      S
# 16      Q
# 17      S
# 18      S
# 19      C
# 20      S
# 21      S
# 22      Q
# 23      S
# 24      S
# 25      S
# 26      C
# 27      S
# 28      Q
# 29      S
# 30      C
# 31      C
# 32      Q
# 33      S
# 34      C
# 35      S
# 36      C
# 37      S
# 38      S
# 39      C
# 40      S
# 41      S
# 42      C
# 43      C
# 44      Q
# 45      S
# 46      Q
# 47      Q
# 48      C
# 49      S
# 50      S
# 51      S
# 52      C
# 53      S
# 54      C
# 55      S
# 56      S
# 57      C
# 58      S
# 59      S
# 60      C
# 61      s
# 62      S
# 63      S
# 64      C
# 65      C
# 66      S
# 67      S
# 68      S
# 69      S
# 70      S
# 71      S
# 72      S
# 73      C
# 74      S
# 75      S
# 76      S
# 77      S
# 78      S
# 79      S
# 80      S
# 81      S
# 82      Q
# ...

# %%
df['Sex'] = df['Sex'].astype('category').cat.codes
df['Embarked'] = df['Embarked'].astype('category').cat.codes
df['Pclass'] = df['Pclass'].astype('category').cat.codes
df['Title1'] = df['Title1'].astype('category').cat.codes
df['Title2'] = df['Title2'].astype('category').cat.codes
df['Cabin'] = df['Cabin'].astype('category').cat.codes
df['Ticket_info'] = df['Ticket_info'].astype('category').cat.codes

# %%
df['Embarked']
# Out:
# 0       2
# 1       0
# 2       2
# 3       2
# 4       2
# 5       1
# 6       2
# 7       2
# 8       2
# 9       0
# 10      2
# 11      2
# 12      2
# 13      2
# 14      2
# 15      2
# 16      1
# 17      2
# 18      2
# 19      0
# 20      2
# 21      2
# 22      1
# 23      2
# 24      2
# 25      2
# 26      0
# 27      2
# 28      1
# 29      2
# 30      0
# 31      0
# 32      1
# 33      2
# 34      0
# 35      2
# 36      0
# 37      2
# 38      2
# 39      0
# 40      2
# 41      2
# 42      0
# 43      0
# 44      1
# 45      2
# 46      1
# 47      1
# 48      0
# 49      2
# 50      2
# 51      2
# 52      0
# 53      2
# 54      0
# 55      2
# 56      2
# 57      0
# 58      2
# 59      2
# 60      0
# 61      3
# 62      2
# 63      2
# 64      0
# 65      0
# 66      2
# 67      2
# 68      2
# 69      2
# 70      2
# 71      2
# 72      2
# 73      0
# 74      2
# 75      2
# 76      2
# 77      2
# 78      2
# 79      2
# 80      2
# 81      2
# 82      1
# ...

# %%
dfAgeNull = df[df["Age"].isnull()]
dfAgeNotNull = df[df["Age"].notnull()]
remove_outlier = dfAgeNotNull[(np.abs(dfAgeNotNull["Fare"]-dfAgeNotNull["Fare"].mean())>(4*dfAgeNotNull["Fare"].std()))|
                      (np.abs(dfAgeNotNull["Family_Size"]-dfAgeNotNull["Family_Size"].mean())>(4*dfAgeNotNull["Family_Size"].std()))]

rfModel_age = RandomForestRegressor(n_estimators=2000,random_state=42)
ageColumns = ['Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title1', 'Title2','Cabin','Ticket_info']
rfModel_age.fit(remove_outlier[ageColumns], remove_outlier["Age"])

ageNullValues = rfModel_age.predict(X= dfAgeNull[ageColumns])
dfAgeNull.loc[:,"Age"] = ageNullValues
df = dfAgeNull.append(dfAgeNotNull)
df.reset_index(inplace=True, drop=True)
# Out:
# /var/folders/4t/yv8q1_017m726db87cx1327m0000gn/T/ipykernel_46849/4149991781.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = dfAgeNull.append(dfAgeNotNull)

# %%
dfTrain = df[pd.notnull(df['Survived'])].sort_values(by=["PassengerId"])
dfTest = df[~pd.notnull(df['Survived'])].sort_values(by=["PassengerId"])

# %%
dfTrain.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Family_Size', 'Title1',
#        'Title2', 'Ticket_info'],
#       dtype='object')

# %%
dfTrain = dfTrain[['Survived', 'Age', 'Embarked', 'Fare',  'Pclass', 'Sex', 'Family_Size', 'Title2','Ticket_info','Cabin']]
dfTest = dfTest[['Age', 'Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title2','Ticket_info','Cabin']]

# %%
dfTrain
# Out:
#      Survived        Age  Embarked      Fare  Pclass  Sex  Family_Size  \
# 263       0.0  22.000000         2    7.2500       2    1            1
# 264       1.0  38.000000         0   71.2833       0    0            1
# 265       1.0  26.000000         2    7.9250       2    0            0
# 266       1.0  35.000000         2   53.1000       0    0            1
# 267       0.0  35.000000         2    8.0500       2    1            0
# 0         0.0  41.326267         1    8.4583       2    1            0
# 268       0.0  54.000000         2   51.8625       0    1            0
# 269       0.0   2.000000         2   21.0750       2    1            4
# 270       1.0  27.000000         2   11.1333       2    0            2
# 271       1.0  14.000000         0   30.0708       1    0            1
# 272       1.0   4.000000         2   16.7000       2    0            2
# 273       1.0  58.000000         2   26.5500       0    0            0
# ...

# %%
rf = RandomForestClassifier(oob_score=True, random_state=1, n_jobs=-1)
param_grid = { "criterion" : ["gini", "entropy"], "min_samples_leaf" : [1, 5, 10], "min_samples_split" : [2, 4, 10, 12, 16, 20], "n_estimators": [50, 100, 400, 700, 1000]}
gs = GridSearchCV(estimator=rf, param_grid=param_grid, scoring='accuracy', cv=3, n_jobs=-1)

gs = gs.fit(dfTrain.iloc[:, 1:], dfTrain.iloc[:, 0])

print(gs.best_score_)
print(gs.best_params_)
# Out:
# 0.8294051627384961
# {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 16, 'n_estimators': 50}

# %%
from sklearn.ensemble import RandomForestClassifier
 
rf = RandomForestClassifier(criterion='gini', 
                             n_estimators=1000,
                             min_samples_split=12,
                             min_samples_leaf=1,
                             oob_score=True,
                             random_state=1,
                             n_jobs=-1) 

rf.fit(dfTrain.iloc[:, 1:], dfTrain.iloc[:, 0])
print("%.4f" % rf.oob_score_)
# Out:
# 0.8305

# %%
pd.concat((pd.DataFrame(dfTrain.iloc[:, 1:].columns, columns = ['variable']), 
           pd.DataFrame(rf.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False)[:20]
# Out:
#       variable  importance
# 4          Sex    0.265756
# 2         Fare    0.164192
# 6       Title2    0.152290
# 0          Age    0.131313
# 3       Pclass    0.090896
# 5  Family_Size    0.070874
# 8        Cabin    0.067064
# 7  Ticket_info    0.031869
# 1     Embarked    0.025746

# %%
rf_res =  rf.predict(dfTest)
submit['Survived'] = rf_res
submit['Survived'] = submit['Survived'].astype(int)
submit.to_csv('submit.csv', index= False)

# %%
submit
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         0
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         0
# 19           911         1
# 20           912         0
# 21           913         1
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         1
# 29           921         0
# 30           922         0
# 31           923         0
# 32           924         1
# ...
